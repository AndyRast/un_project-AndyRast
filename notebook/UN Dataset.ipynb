# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# 1. First six rows of gdp_df

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv',nrows=6868)
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN

# %% [markdown]
# 2. First six rows of internet_df

# %%
internet_df = pd.read_csv('../data/internet_use.csv',nrows=4495)
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes  Unnamed: 4  Unnamed: 5
# 0     Afghanistan  2014  6.390000              NaN         NaN         NaN
# 1     Afghanistan  2013  5.900000              NaN         NaN         NaN
# 2     Afghanistan  2012  5.454545              NaN         NaN         NaN
# 3     Afghanistan  2011  5.000000              NaN         NaN         NaN
# 4     Afghanistan  2010  4.000000              NaN         NaN         NaN
# 5     Afghanistan  2009  3.550000              NaN         NaN         NaN

# %% [markdown]
# 3. Rows and Columns of gdp_df

# %%
gdp_df.shape
# Out:
# (6868, 4)

# %% [markdown]
# 4. Rows and Columns of internet_df

# %%
internet_df.shape
# Out:
# (4495, 6)

# %% [markdown]
# 6. Data types in gdp_df

# %%
print(type(gdp_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 7. Data types in internet_df

# %%
print(type(internet_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 8. Last ten rows of gdp_df

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6858        Zimbabwe  1999  3600.849291              NaN
# 6859        Zimbabwe  1998  3653.920016              NaN
# 6860        Zimbabwe  1997  3580.048793              NaN
# 6861        Zimbabwe  1996  3520.430146              NaN
# 6862        Zimbabwe  1995  3226.413930              NaN
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN

# %% [markdown]
# 9. Last ten rows of internet_df

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes  Unnamed: 4  Unnamed: 5
# 4485        Zimbabwe  2002  3.994356              NaN         NaN         NaN
# 4486        Zimbabwe  2001  0.799846              NaN         NaN         NaN
# 4487        Zimbabwe  2000  0.401434              NaN         NaN         NaN
# 4488        Zimbabwe  1999  0.161676              NaN         NaN         NaN
# 4489        Zimbabwe  1998  0.081648              NaN         NaN         NaN
# 4490        Zimbabwe  1997  0.033080              NaN         NaN         NaN
# 4491        Zimbabwe  1996  0.016790              NaN         NaN         NaN
# 4492        Zimbabwe  1995  0.007684              NaN         NaN         NaN
# 4493        Zimbabwe  1994  0.001739              NaN         NaN         NaN
# 4494        Zimbabwe  1990  0.000000              NaN         NaN         NaN

# %% [markdown]
# 10. Drop "Value Footnotes" for gdp_df

# %%
gdp_df = gdp_df.drop(columns = ['Value Footnotes'])

# %% [markdown]
# 11. Drop "Value Footnotes" in internet_df

# %%
internet_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %%
internet_df = internet_df.drop(columns = ['Value Footnotes', 'Unnamed: 4', 'Unnamed: 5'])

# %% [markdown]
# 12. Change the columns for the GDP Per Capita DataFrame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value'], dtype='object')

# %%
gdp_df.columns = ['Country', 'Year', 'GDP_Per_Capita']
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %% [markdown]
# 13. Change the columns for the Internet Users DataFrame to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’

# %%
internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# 13. Merge the two DataFrames to one. Merge all rows from each of the two DataFrames. Call the new DataFrame gdp_and_internet_use

# %%
gdp_and_internet_use = gdp_df.merge(internet_df, on=['Year','Country'], how='inner')
gdp_and_internet_use
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2014     2102.385234            6.390000
# 1     Afghanistan  2013     2116.465454            5.900000
# 2     Afghanistan  2012     2075.491747            5.454545
# 3     Afghanistan  2011     1904.559799            5.000000
# 4     Afghanistan  2010     1957.029338            4.000000
# ...           ...   ...             ...                 ...
# 3453     Zimbabwe  1997     3580.048793            0.033080
# 3454     Zimbabwe  1996     3520.430146            0.016790
# 3455     Zimbabwe  1995     3226.413930            0.007684
# 3456     Zimbabwe  1994     3263.934978            0.001739
# 3457     Zimbabwe  1990     3324.348171            0.000000
#
# [3458 rows x 4 columns]

# %% [markdown]
# 14. Look at the first five rows of your new DataFrame to confirm it merged correctly

# %%
gdp_and_internet_use.head()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2014     2102.385234            6.390000
# 1  Afghanistan  2013     2116.465454            5.900000
# 2  Afghanistan  2012     2075.491747            5.454545
# 3  Afghanistan  2011     1904.559799            5.000000
# 4  Afghanistan  2010     1957.029338            4.000000

# %% [markdown]
# 15. Look at the last five rows to make sure the data is clean and as expected

# %%
gdp_and_internet_use.tail()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3453  Zimbabwe  1997     3580.048793            0.033080
# 3454  Zimbabwe  1996     3520.430146            0.016790
# 3455  Zimbabwe  1995     3226.413930            0.007684
# 3456  Zimbabwe  1994     3263.934978            0.001739
# 3457  Zimbabwe  1990     3324.348171            0.000000

# %% [markdown]
# 16. Subset the combined DataFrame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly

# %%
year_filter = gdp_and_internet_use[gdp_and_internet_use['Year'].isin([2004,2009,2014])]
year_filter
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2014     2102.385234            6.390000
# 5     Afghanistan  2009     1758.904043            3.550000
# 10    Afghanistan  2004     1200.278256            0.105809
# 13        Albania  2014    11623.866680           60.100000
# 18        Albania  2009    10346.864200           41.200000
# ...           ...   ...             ...                 ...
# 3419       Zambia  2009     2917.516220            6.310000
# 3424       Zambia  2004     2261.766537            2.013550
# 3436     Zimbabwe  2014     2955.240287           19.890000
# 3441     Zimbabwe  2009     1925.364381           11.360000
# 3446     Zimbabwe  2004     2480.859342            6.564045
#
# [482 rows x 4 columns]

# %% [markdown]
# 17. Create three new DataFrames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long

# %%
gdpinternet2004 = year_filter[year_filter['Year'].isin([2004])]
gdpinternet2004
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 10            Afghanistan  2004     1200.278256            0.105809
# 23                Albania  2004     7604.838002            2.420388
# 44                Algeria  2004    10058.435940            4.634475
# 66                 Angola  2004     5593.241537            0.464815
# 86    Antigua and Barbuda  2004    18745.681530           24.266544
# ...                   ...   ...             ...                 ...
# 3361              Uruguay  2004    12479.966870           17.063098
# 3383           Uzbekistan  2004     3221.189333            2.593725
# 3404              Vanuatu  2004     2792.356252            4.746603
# 3424               Zambia  2004     2261.766537            2.013550
# 3446             Zimbabwe  2004     2480.859342            6.564045
#
# [157 rows x 4 columns]

# %%
gdpinternet2009 = year_filter[year_filter['Year'].isin([2009])]
gdpinternet2009
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5             Afghanistan  2009     1758.904043            3.550000
# 18                Albania  2009    10346.864200           41.200000
# 39                Algeria  2009    10782.361400           11.230000
# 61                 Angola  2009     7643.493749            6.000000
# 81    Antigua and Barbuda  2009    20046.839020           42.000000
# ...                   ...   ...             ...                 ...
# 3356              Uruguay  2009    16477.823860           41.800000
# 3378           Uzbekistan  2009     4446.863606           17.058216
# 3399              Vanuatu  2009     3270.529800            7.500000
# 3419               Zambia  2009     2917.516220            6.310000
# 3441             Zimbabwe  2009     1925.364381           11.360000
#
# [162 rows x 4 columns]

# %%
gdpinternet2014 = year_filter[year_filter['Year'].isin([2014])]
gdpinternet2014
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0             Afghanistan  2014     2102.385234                6.39
# 13                Albania  2014    11623.866680               60.10
# 34                Algeria  2014    11512.705410               18.09
# 56                 Angola  2014     8239.828837               21.26
# 76    Antigua and Barbuda  2014    18104.241470               64.00
# ...                   ...   ...             ...                 ...
# 3351              Uruguay  2014    20582.168950               61.46
# 3373           Uzbekistan  2014     5764.492705               43.55
# 3394              Vanuatu  2014     3116.077025               18.80
# 3414               Zambia  2014     3450.046561               17.34
# 3436             Zimbabwe  2014     2955.240287               19.89
#
# [163 rows x 4 columns]

# %% [markdown]
# 18. Which country had the highest percentage of internet users in 2014? What was the percentage? (Try typing the first 3 letters of your DataFrame name and hitting the tab key for auto-complete options)

# %%
gdpinternet2014.sort_values(by='Internet_Users_Pct', ascending=False).head()
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1381     Iceland  2014     49652.14950               98.16
# 372      Bermuda  2014     77361.10488               96.80
# 2296      Norway  2014     62589.37355               96.30
# 854      Denmark  2014     52214.53775               95.99
# 1798  Luxembourg  2014    108760.91600               94.67

# %% [markdown]
# 19. Which country had the lowest percentage of internet users in 2014? What was the percentage?

# %%
gdpinternet2014.sort_values(by='Internet_Users_Pct', ascending=True).head()
# Out:
#            Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3087   Timor-Leste  2014     3264.568070                1.14
# 540        Burundi  2014      886.235777                1.38
# 1261        Guinea  2014     2061.760973                1.72
# 2256         Niger  2014     1127.615541                1.95
# 2728  Sierra Leone  2014     1997.511853                2.10

# %% [markdown]
# 20. Repeat for 2004 and 2009.

# %%
gdpinternet2004.sort_values(by='Internet_Users_Pct', ascending=False).head()
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2985   Sweden  2004     44496.02340               83.89
# 1391  Iceland  2004     45145.54566               83.88
# 864   Denmark  2004     50607.62897               80.93
# 2306   Norway  2004     60893.41099               77.69
# 1063  Finland  2004     43760.27915               72.39

# %%
gdpinternet2004.sort_values(by='Internet_Users_Pct', ascending=True).head()
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2132      Myanmar  2004     1696.881760            0.024337
# 1759      Liberia  2004     1181.546158            0.031011
# 3035   Tajikistan  2004     1737.743630            0.077480
# 10    Afghanistan  2004     1200.278256            0.105809
# 1019     Ethiopia  2004      793.093785            0.155335

# %%
gdpinternet2009.sort_values(by='Internet_Users_Pct', ascending=False).head()
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1386      Iceland  2009     48177.08412               93.00
# 2301       Norway  2009     61886.56450               92.08
# 2980       Sweden  2009     45638.03558               91.00
# 2190  Netherlands  2009     51772.42493               89.63
# 1803   Luxembourg  2009    104932.81200               87.31

# %%
gdpinternet2009.sort_values(by='Internet_Users_Pct', ascending=True).head()
# Out:
#            Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3092   Timor-Leste  2009     2724.770973            0.185252
# 2127       Myanmar  2009     2874.780227            0.220000
# 2733  Sierra Leone  2009     1372.392285            0.260000
# 570       Cambodia  2009     2603.583778            0.530000
# 1014      Ethiopia  2009     1150.206179            0.540000

# %% [markdown]
# 21. Which country had the highest gdp per capita in 2014? What was the gdp per capita?

# %%
gdpinternet2014.sort_values(by='GDP_Per_Capita', ascending=False).head()
# Out:
#              Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1798      Luxembourg  2014    108760.91600               94.67
# 2542           Qatar  2014     95578.41697               91.49
# 2751       Singapore  2014     87808.66316               82.00
# 372          Bermuda  2014     77361.10488               96.80
# 627   Cayman Islands  2014     66207.44723               74.10

# %% [markdown]
# 22. Which country had the lowest gdp per capita in 2014? What was the gdp per capita?

# %%
gdpinternet2014.sort_values(by='GDP_Per_Capita', ascending=True).head()
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 540      Burundi  2014      886.235777                1.38
# 1842      Malawi  2014     1027.208496                5.83
# 2256       Niger  2014     1127.615541                1.95
# 2102  Mozambique  2014     1217.090210                5.94
# 3098        Togo  2014     1404.132938                5.70

# %% [markdown]
# 23. Create some scatterplots:
# a. 2004 Percent Using the Internet vs GDP Per Capita
# b. 2009 Percent Using the Internet vs GDP Per Capita
# c. 2014 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(gdpinternet2004.GDP_Per_Capita, gdpinternet2004.Internet_Users_Pct);

# %%
plt.scatter(gdpinternet2009.GDP_Per_Capita, gdpinternet2009.Internet_Users_Pct);

# %%
plt.scatter(gdpinternet2014.GDP_Per_Capita, gdpinternet2014.Internet_Users_Pct);

# %% [markdown]
# 24. Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell

# %% [markdown]
# Internet users increase with GDP. Between 2004 and 2014 more people in low GDP countries used the internet.

# %% [markdown]
# 25. Look at the distribution of gdp per capita values for 2014. Is it unimodal?

# %%
plt.hist(gdpinternet2014.GDP_Per_Capita, bins = 15);

# %% [markdown]
# 26. Look at the distribution of Internet Use for 2014. Is it unimodal?

# %%
plt.hist(gdpinternet2014.Internet_Users_Pct, bins = 15);

# %% [markdown]
# 27. What are the top 5 countries in terms of internet use in 2014?

# %%
top_2014 = gdpinternet2014.sort_values(by='Internet_Users_Pct', ascending=False).head()
top_2014
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1381     Iceland  2014     49652.14950               98.16
# 372      Bermuda  2014     77361.10488               96.80
# 2296      Norway  2014     62589.37355               96.30
# 854      Denmark  2014     52214.53775               95.99
# 1798  Luxembourg  2014    108760.91600               94.67

# %%
top_5_list = top_2014.Country.tolist()
top_5_list
# Out:
# ['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Luxembourg']

# %% [markdown]
# 28. Create a DataFrame called top_5_internet from the combined DataFrame that has all three years for the 5 countries that had the greatest 2014 internet usage. You should have 15 rows. Check that this is true

# %%
top_internet_filter = year_filter[year_filter['Country'].isin(top_5_list)]
top_internet_filter
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 372      Bermuda  2014     77361.10488           96.800000
# 377      Bermuda  2009     89961.98274           83.250000
# 382      Bermuda  2004     90195.81103           60.990867
# 854      Denmark  2014     52214.53775           95.990000
# 859      Denmark  2009     50274.07570           86.840000
# 864      Denmark  2004     50607.62897           80.930000
# 1381     Iceland  2014     49652.14950           98.160000
# 1386     Iceland  2009     48177.08412           93.000000
# 1391     Iceland  2004     45145.54566           83.880000
# 1798  Luxembourg  2014    108760.91600           94.670000
# 1803  Luxembourg  2009    104932.81200           87.310000
# 1808  Luxembourg  2004    102708.21250           65.880000
# 2296      Norway  2014     62589.37355           96.300000
# 2301      Norway  2009     61886.56450           92.080000
# 2306      Norway  2004     60893.41099           77.690000

# %% [markdown]
# 29. Create a seaborn FacetGrid to show the internet usage trend across the years 2004, 2009, and 2014 for these 5 countries (those with the highest reported internet use in 2014). Which country had the greatest growth between 2004 and 2014?

# %%
sns.relplot(data=top_internet_filter, x="Country", y="Internet_Users_Pct", hue="Country")

# %% [markdown]
# 30. Repeat the steps above to look at the trend for the 5 countries with the lowest 2014 internet usage. Which country has consistently had the least internet use?

# %%
bottom_2014 = gdpinternet2014.sort_values(by='Internet_Users_Pct', ascending=True).head()
bottom_2014
# Out:
#            Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3087   Timor-Leste  2014     3264.568070                1.14
# 540        Burundi  2014      886.235777                1.38
# 1261        Guinea  2014     2061.760973                1.72
# 2256         Niger  2014     1127.615541                1.95
# 2728  Sierra Leone  2014     1997.511853                2.10

# %%
bottom_5_list = bottom_2014.Country.tolist()
bottom_5_list
# Out:
# ['Timor-Leste', 'Burundi', 'Guinea', 'Niger', 'Sierra Leone']

# %%
bottom_internet_filter = year_filter[year_filter['Country'].isin(bottom_5_list)]
bottom_internet_filter
# Out:
#            Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 540        Burundi  2014      886.235777            1.380000
# 545        Burundi  2009      831.564131            0.900000
# 550        Burundi  2004      817.460585            0.349060
# 1261        Guinea  2014     2061.760973            1.720000
# 1266        Guinea  2009     1825.576637            0.940000
# 1271        Guinea  2004     1778.079082            0.508819
# 2256         Niger  2014     1127.615541            1.950000
# 2261         Niger  2009      992.409977            0.760000
# 2266         Niger  2004      929.883920            0.189934
# 2728  Sierra Leone  2014     1997.511853            2.100000
# 2733  Sierra Leone  2009     1372.392285            0.260000
# 2738  Sierra Leone  2004     1237.630244            0.203008
# 3087   Timor-Leste  2014     3264.568070            1.140000
# 3092   Timor-Leste  2009     2724.770973            0.185252

# %%
sns.relplot(data=bottom_internet_filter, x="Country", y="Internet_Users_Pct", hue="Country")

# %% [markdown]
# 31. Find the top 5 countries for 2014 in terms of GDP per capita; create a DataFrame to look at 10-year trends (use 2004, 2009, 2014 to look at the 10-year trend) in gdp per capita for the 5 countries with the highest 2014 GDP per capita. Use a seaborn facet grid for this.

# %%
top_2014_gdp = gdpinternet2014.sort_values(by='GDP_Per_Capita', ascending=False).head()
top_2014_gdp
# Out:
#              Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1798      Luxembourg  2014    108760.91600               94.67
# 2542           Qatar  2014     95578.41697               91.49
# 2751       Singapore  2014     87808.66316               82.00
# 372          Bermuda  2014     77361.10488               96.80
# 627   Cayman Islands  2014     66207.44723               74.10

# %%
top_5_gdp_list = top_2014_gdp.Country.tolist()
top_5_gdp_list
# Out:
# ['Luxembourg', 'Qatar', 'Singapore', 'Bermuda', 'Cayman Islands']

# %%
top_gdp_filter = year_filter[year_filter['Country'].isin(top_5_gdp_list)]
top_gdp_filter
# Out:
#              Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 372          Bermuda  2014     77361.10488           96.800000
# 377          Bermuda  2009     89961.98274           83.250000
# 382          Bermuda  2004     90195.81103           60.990867
# 627   Cayman Islands  2014     66207.44723           74.100000
# 632   Cayman Islands  2009     70300.33486           64.500000
# 1798      Luxembourg  2014    108760.91600           94.670000
# 1803      Luxembourg  2009    104932.81200           87.310000
# 1808      Luxembourg  2004    102708.21250           65.880000
# 2542           Qatar  2014     95578.41697           91.490000
# 2547           Qatar  2009     89954.51999           53.100000
# 2552           Qatar  2004     93748.30122           20.701648
# 2751       Singapore  2014     87808.66316           82.000000
# 2756       Singapore  2009     69466.58175           69.000000
# 2761       Singapore  2004     63901.71637           62.000000

# %%
sns.relplot(data=top_gdp_filter, x="Country", y="GDP_Per_Capita", hue="Country")

# %% [markdown]
# 32. Repeat this one more time to look at 10-year trend for the 5 countries for 2014 with the lowest GDP per capita.

# %%
bottom_2014_gdp = gdpinternet2014.sort_values(by='GDP_Per_Capita', ascending=True).head()
bottom_2014_gdp
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 540      Burundi  2014      886.235777                1.38
# 1842      Malawi  2014     1027.208496                5.83
# 2256       Niger  2014     1127.615541                1.95
# 2102  Mozambique  2014     1217.090210                5.94
# 3098        Togo  2014     1404.132938                5.70

# %%
bottom_5_gdp_list = bottom_2014_gdp.Country.tolist()
bottom_5_gdp_list
# Out:
# ['Burundi', 'Malawi', 'Niger', 'Mozambique', 'Togo']

# %%
bottom_gdp_filter = year_filter[year_filter['Country'].isin(bottom_5_gdp_list)]
bottom_gdp_filter
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 540      Burundi  2014      886.235777            1.380000
# 545      Burundi  2009      831.564131            0.900000
# 550      Burundi  2004      817.460585            0.349060
# 1842      Malawi  2014     1027.208496            5.830000
# 1847      Malawi  2009      932.867635            1.070000
# 1852      Malawi  2004      775.346132            0.347505
# 2102  Mozambique  2014     1217.090210            5.940000
# 2107  Mozambique  2009      991.323181            2.680000
# 2112  Mozambique  2004      792.727155            0.679448
# 2256       Niger  2014     1127.615541            1.950000
# 2261       Niger  2009      992.409977            0.760000
# 2266       Niger  2004      929.883920            0.189934
# 3098        Togo  2014     1404.132938            5.700000
# 3103        Togo  2009     1186.114587            2.600000
# 3108        Togo  2004     1276.676272            1.500000

# %%
sns.relplot(data=bottom_gdp_filter, x="Country", y="GDP_Per_Capita", hue="Country")

# %% [markdown]
# 33. Is there anything surprising or unusual in any of these plots? Searching on the internet, can you find any possible explanations for unusual findings?
